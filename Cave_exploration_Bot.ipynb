# %% [markdown]
# <a href="https://colab.research.google.com/github/Shinjanip/Cave_Exploration_Rover/blob/main/Cave_exploration_Bot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 30.7 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="unauthorized")
project = rf.workspace("project-jihlz").project("crack-in-rock")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.8/95.8 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 17.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 67.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 133.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_7025/1121039328.py in <cell line: 0>()
# ...

# %%
# !pip install ultralytics

from ultralytics import YOLO

# Load the brain
model = YOLO('yolov8n.pt')

# Start studying!
results = model.train(data='My-First-Project-1/data.yaml', epochs=25, imgsz=640)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 30.9 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.32 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="ERSCloYqxPzTIy3WR7Sr")
project = rf.workspace("shinjanis-workspace").project("my-first-project-pzf0p")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.8/95.8 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 19.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 91.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 110.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to My-First-Project-1 in yolov8:: 100%|██████████| 512/512 [00:00<00:00, 8440.97it/s]

# %%
# !unzip -q My-First-Project-1 -d /content/my_dataset
# Out:
# unzip:  cannot find or open My-First-Project-1, My-First-Project-1.zip or My-First-Project-1.ZIP.

# %%
import glob
import shutil

# Tell Colab to search every single folder for the best.pt file
print("Searching for your trained model...")
files = glob.glob('/**/best.pt', recursive=True)

if files:
    print(f"🎯 Found it! It was hiding at: {files[0]}")
    # Copy it straight to the main folder so it's impossible to miss
    shutil.copy(files[0], '/content/best.pt')
    print("✅ I moved a copy to your main folder. Click the 'Refresh' icon on the left, and you will see 'best.pt' ready to download!")
else:
    print("❌ Couldn't find it. Scroll up and make sure the training cell hit 25/25 epochs and didn't crash!")
# Out:
# Searching for your trained model...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_7025/108688983.py in <cell line: 0>()
#       4 # Tell Colab to search every single folder for the best.pt file
#       5 print("Searching for your trained model...")
# ----> 6 files = glob.glob('/**/best.pt', recursive=True)
#       7
#       8 if files:
#
# /usr/lib/python3.12/glob.py in glob(pathname, root_dir, dir_fd, recursive, include_hidden)
#      26     zero or more directories and subdirectories.
#      27     """
# ---> 28     return list(iglob(pathname, root_dir=root_dir, dir_fd=dir_fd, recursive=recursive,
#      29                       include_hidden=include_hidden))
#      30
#
# /usr/lib/python3.12/glob.py in _iglob(pathname, root_dir, dir_fd, recursive, dironly, include_hidden)
#      94     else:
#      95         glob_in_dir = _glob0
# ...
